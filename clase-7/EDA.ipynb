# %%
import numpy as np

import matplotlib.pyplot as plt

# Parámetros de la distribución gaussiana
mu = 0  # Media
sigma = 1  # Desviación estándar

# Generar datos para la distribución
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)
y = (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mu) / sigma)**2)

# Graficar la distribución
plt.plot(x, y, label=f'$\mu={mu}, \sigma={sigma}$')
plt.title('Distribución Gaussiana')
plt.xlabel('x')
plt.ylabel('Densidad de probabilidad')
plt.legend()
plt.grid()
plt.show()
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\m'
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:14: SyntaxWarning: invalid escape sequence '\m'
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/ly/g9twzd3d63d1cprw4rh_7z5m0000gn/T/ipykernel_54192/474793215.py:14: SyntaxWarning: invalid escape sequence '\m'
#   plt.plot(x, y, label=f'$\mu={mu}, \sigma={sigma}$')
# /var/folders/ly/g9twzd3d63d1cprw4rh_7z5m0000gn/T/ipykernel_54192/474793215.py:14: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(x, y, label=f'$\mu={mu}, \sigma={sigma}$')
